# %%
import matplotlib.pyplot as plt


Number = [10, 100, 1000,10000, 100000, 1000000]
Bubble_sort = [0.0030148, 0.000999, 0.00599, 0.00799, 0.05898, 0.5446]
Selection_sort = [0.000999, 0.00199, 0.266, 21.692, 220.999,2340.455]
Insertion_sort = [0.0009992, 0.001, 0.00399, 0.00599, 0.0659, 0.78255]
plt.plot(Number, Insertion_sort, color='g')
#plt.plot(Number, Selection_sort, color='orange')
plt.plot(Number, Bubble_sort, color='c')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Best Case Bubble sort/ Insertion sort')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Number = [10, 100, 1000,10000, 100000, 1000000]
Bubble_sort = [0.0030148, 0.000999, 0.00599, 0.00799, 0.05898, 0.5446]
Selection_sort = [0.000999, 0.00199, 0.266, 21.692, 220.999,2340.455]
Insertion_sort = [0.0009992, 0.001, 0.00399, 0.00599, 0.0659, 0.78255]

# %%
plt.plot(Number, Insertion_sort, color='g')
#plt.plot(Number, Selection_sort, color='orange')
plt.plot(Number, Bubble_sort, color='c')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Best Case Bubble sort/ Insertion sort')
plt.show()

# %%
#plt.plot(Number, Insertion_sort, color='g')
plt.plot(Number, Selection_sort, color='r')
#plt.plot(Number, Bubble_sort, color='c')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Best Case selection sort')
plt.show()

# %%
Number = [10, 100, 1000,10000, 100000, 1000000]
heap_sort = [0.0000098, 0.00065, 0.000889, 0.0121, 0.123,1.12]
merge_sort = [0.000009, 0.0004, 0.000998, 0.0109, 0.112,1.19]
quick_sort = [0.000009998, 0.000235, 0.0009992, 0.01119, 0.1053,1.22]

# %%
plt.plot(Number, heap_sort, color='C4' , label = 'heap_sort')
plt.plot(Number, merge_sort, color='C5' , label = 'merge_sort')
plt.plot(Number, quick_sort, color='C6' , label = 'quick_sort')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Best Cases for Heap/Merge/Quick sorts')
plt.legend()
plt.show()

# %%
Number = [10, 100, 1000,10000, 100000, 1000000]
heap_sort = [0.0000098, 0.00065, 0.0159, 0.2465, 2.581,36.0813]
merge_sort = [0.000009, 0.0004, 0.0130, 0.2650, 2.672,39.0153]
quick_sort = [0.000009998, 0.000235, 0.0126, 0.2624, 2.981,35.998]

# %%
plt.plot(Number, heap_sort, color='C4' , label = 'heap_sort')
plt.plot(Number, merge_sort, color='C5' , label = 'merge_sort')
plt.plot(Number, quick_sort, color='C6' , label = 'quick_sort')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Average Cases for Heap/Merge/Quick sorts')
plt.legend()
plt.show()

# %%
Number = [10, 100, 1000,10000, 100000, 1000000]
heap_sort = [0.0000098, 0.00065, 0.0159, 0.2465, 3.581,36.512]
merge_sort = [0.000009, 0.0004, 0.000997, 0.01299, 0.13574,1.268]
quick_sort = [0.000009998, 0.000235, 0.0126, 0.2624, 2.981,35.998]

# %%
plt.plot(Number, heap_sort, color='C2' , label = 'heap_sort')
plt.plot(Number, merge_sort, color='C5' , label = 'merge_sort')
plt.plot(Number, quick_sort, color='C7' , label = 'quick_sort')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Mid Cases for Bubble/Selection/Insertion sorts')
plt.legend()
plt.show()

# %%
Number = [10, 100, 1000,10000]
Bubble_sort = [0.000499, 0.0044, 0.415, 43.38]
Selection_sort = [0.0004992, 0.002494, 0.22159, 22.835]
Insertion_sort = [0.0004991, 0.00334, 0.3115, 29.38]

# %%
plt.plot(Number, Bubble_sort, color='C2' , label = 'Bubble_sort')
plt.plot(Number, Selection_sort, color='C5' , label = 'Selection_sort')
plt.plot(Number, Insertion_sort, color='C7' , label = 'Insertion_sort')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Mid Cases for Bubble/Selection/Insertion sorts')
plt.legend()
plt.show()

# %%
Number = [10, 100, 1000,10000]
Bubble_sort = [0.000498, 0.00249, 0.2166, 28.3518]
Selection_sort = [0.0004992, 0.002494, 0.22159, 27.835]
Insertion_sort = [0.0004991, 0.00334, 0.3115, 25.98]

# %%
plt.plot(Number, Bubble_sort, color='C2' , label = 'Bubble_sort')
plt.plot(Number, Selection_sort, color='C5' , label = 'Selection_sort')
plt.plot(Number, Insertion_sort, color='C7' , label = 'Insertion_sort')
plt.xlabel('Time')
plt.ylabel('Number')
plt.title('Worst Cases for Bubble/Selection/Insertion sorts')
plt.legend()
plt.show()
